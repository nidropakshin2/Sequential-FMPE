# %%
import torch
import numpy as np 
import matplotlib.pyplot as plt 
from torch import nn, Tensor
import yaml
import time
import os

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
if not os.path.exists("./models"):
    os.mkdir("./models")
# Out:
# cpu

# %%
def sample_log_uniform(low, high, size, device='cpu'):
    """
    low, high: scalars (floats), low > 0
    size: tuple, e.g. (B,)
    """
    u = torch.rand(size, device=device)
    log_low = torch.log(torch.tensor(low, device=device))
    log_high = torch.log(torch.tensor(high, device=device))
    return torch.exp(log_low + u * (log_high - log_low)).to(device)


def sample_prior(B, device='cpu'):
    gamma = sample_log_uniform(0.05, 0.5, (*B, 1), device)
    R0 = sample_log_uniform(0.5, 5.0, (*B, 1), device)
    beta = R0 * gamma
    return torch.cat([beta, gamma], dim=1).to(device)


def sample_init_dist(B, device='cpu'):
    # return torch.rand(size=(B, 2)).to(device)
    return torch.rand(size=(*B, 2))

samples = sample_log_uniform(0.01, 10.0, (100_000,))
plt.hist(torch.log(samples).numpy(), bins=100)
plt.xlabel("log(x)")
plt.show()

# %%
def simulate(phi, sir=(1000, 100, 0), T=90):
    S, I, R = sir
    S = torch.zeros(phi.shape[0], device=phi.device) + S
    I = torch.zeros(phi.shape[0], device=phi.device) + I
    R = torch.zeros(phi.shape[0], device=phi.device) + R
    N = S + I + R
    
    states = torch.zeros(phi.shape[0], T, 3, device=phi.device)
    for t in range(0, T):
        states[:, t, 0] = S
        states[:, t, 1] = I
        states[:, t, 2] = R

        p_inf = 1 - torch.exp(-phi[:, 0] * I / N)
        p_rec = 1 - torch.exp(-phi[:, 1])

        new_inf = torch.binomial(S, p_inf)
        new_rec = torch.binomial(I, p_rec)

        S = S - new_inf
        I = I + new_inf - new_rec
        R = R + new_rec

    states[:, T-1, 0] = S
    states[:, T-1, 1] = I
    states[:, T-1, 2] = R
    return states        
    
sir = (1000, 100, 0)
phi = sample_prior((2,))
phi[1, :] = 1.5*phi[0, :] 
print(phi)
x_0, x_1 = simulate(phi, sir, 90).cpu()
S, I, R = x_0[:, 0], x_0[:, 1], x_0[:, 2]
plt.plot(S)
plt.plot(I)
plt.plot(R)
S, I, R = x_1[:, 0], x_1[:, 1], x_1[:, 2]
plt.plot(S)
plt.plot(I)
plt.plot(R)
# Out:
# tensor([[0.3884, 0.3356],
#         [0.5826, 0.5035]])

# %%
def safe_div(a, b, eps=1e-8):
    return a / (b + eps)

def handmade_summary(x, eps=1e-8):
    S = x[:, :, 0]
    I = x[:, :, 1]
    R = x[:, :, 2]
    batch, T = I.shape

    N = S[:, 0] + I[:, 0] + R[:, 0]
    N = N.clamp(min=eps)

    
    I_peak, t_peak = I.max(dim=1)            
    t_peak = t_peak.to(torch.float32) / float(max(1, T - 1))
    t_peak = t_peak.unsqueeze(1)             

    I_peak_frac = safe_div(I_peak, N).unsqueeze(1)
    
    I_mean_frac = safe_div(I.mean(dim=1), N).unsqueeze(1)

    R_final_frac = safe_div(R[:, -1], N).unsqueeze(1)

    S_final_frac = safe_div(S[:, -1], N).unsqueeze(1)

    
    s = torch.cat([t_peak, I_peak_frac, I_mean_frac, R_final_frac, S_final_frac], dim=1).to(x.device)
    
    B = torch.tensor([[-0.6543, -1.0543,  0.4823, -0.4612,  0.7340],
                      [ 2.6280, -1.6988, -0.6246, -0.0949, -0.3497],
                      [ 0.4116, -0.8507, -0.1116, -0.5067,  1.4959],
                      [-0.2124, -0.1211, -0.8651, -1.2937,  1.2938],
                      [ 0.0257, -0.9242, -1.4133,  0.3826, -1.0719]]).to(x.device)
    
    s = torch.matmul(s, B)
    
    return s

def visualize_summary_features(summary):
    phi = sample_prior((3000,))
    x = simulate(phi, (1000, 500, 0), 90)
    s = summary(x)
    _, ax = plt.subplots(s.shape[1], 1, sharey=True)
    for i in range(s.shape[1]):
        ax[i].scatter(torch.log(phi[:, 0]), torch.log(phi[:, 1]), c=s[:, i], s=1)
        # ax[i].scatter(phi[:, 0], phi[:, 1], c=s[:, i], s=1)

visualize_summary_features(handmade_summary)

# %%
class CondFlow(nn.Module):
    def __init__(self, phi_dim, x_dim, h):
        super().__init__()
        self.dim = phi_dim
        self.net = nn.Sequential(
            nn.Linear(1 + x_dim + phi_dim, h), nn.ReLU(),
            nn.Linear(h, h), nn.ReLU(),
            nn.Linear(h, h), nn.ReLU(),
            nn.Linear(h, phi_dim)
        )
    
    def forward(self, t, x, phi):
        return self.net(torch.cat((t, x, phi), dim=-1))
    
    def step(self, phi, x, t_start, t_end):
        # t_start = t_start.view(1, 1).expand(phi.shape[0], 1)
        # t_end = t_end.view(1, 1).expand(phi.shape[0], 1)
        t_start = t_start.expand(*phi.shape[:-1], 1)
        t_end = t_end.expand(*phi.shape[:-1], 1)
        
        
        t_mid = (t_end + t_start) / 2
        phi_mid = phi + self.forward(t=t_start, x=x, phi=phi) * (t_mid - t_start)
        return  phi + self.forward(t=t_mid, x=x, phi=phi_mid) * (t_end - t_start)

model = CondFlow(2, 5, 16)
beta, gamma = 0.5, 0.5
sir = (1000, 100, 0)

phi = torch.tensor([[beta, gamma]])
x = simulate(phi, sir, 90)
s = handmade_summary(x)
t = torch.tensor([[0.0]])
model(t=t, x=s, phi=phi)
# Out:
# tensor([[-0.2000, -0.1459]], grad_fn=<AddmmBackward0>)

# %%
def plot_posterior(posterior, 
                   real_phi,
                   log_scale=False,
                   xlim=None,
                   ylim=None):
    mean = posterior.mean(dim=0).unsqueeze(0)
    # std = (posterior - mean[:, None, :]).pow(2).mean(dim=1).pow(0.5)
    std = posterior.std(dim=0).unsqueeze(0)

    if phi.shape[0] == 1:
        _, ax = plt.subplots(1, 1, figsize=(4, 4))
        if log_scale:
            # ax.scatter(torch.log(posterior[0, :, 0]).cpu(), torch.log(posterior[0, :, 1]).cpu(), s=1, label="Posterior")
            ax.scatter(torch.log(posterior[:, 0]).cpu(), torch.log(posterior[:, 1]).cpu(), s=1, label="Posterior")
            ax.scatter(torch.log(real_phi[0, 0]).cpu(), torch.log(real_phi[0, 1]).cpu(), s=10, label="True phi")
            ax.scatter(torch.log(mean[0, 0]).cpu(), torch.log(mean[0, 1]).cpu(), s=10, label="Mean", color="red")
        else:
            # ax.scatter(posterior[0, :, 0].cpu(), posterior[0, :, 1].cpu(), s=1, label="Posterior")
            ax.scatter(posterior[:, 0].cpu(), posterior[:, 1].cpu(), s=1, label="Posterior")
            ax.scatter(real_phi[0, 0].cpu(), real_phi[0, 1].cpu(), s=10, label="True phi")
            ax.scatter(mean[0, 0].cpu(), mean[0, 1].cpu(), s=10, label="Mean", color="red")
            print(mean)
        if xlim != None:
            ax.set_xlim(xlim)
        if ylim != None:
            ax.set_ylim(ylim)
        ax.legend()
    
    else:
        _, ax = plt.subplots(max(real_phi.shape[0], 2), 1, figsize=(4, 4 * (max(real_phi.shape[0], 2))))

        for i in range(x.shape[0]):
            if log_scale:
                ax[i].scatter(torch.log(posterior[i, :, 0]).cpu(), torch.log(posterior[i, :, 1]).cpu(), s=1, label="Posterior")
                ax[i].scatter(torch.log(real_phi[i, 0]).cpu(), torch.log(real_phi[i, 1]).cpu(), s=10, label="True phi")
                ax[i].scatter(torch.log(mean[i, 0]).cpu(), torch.log(mean[i, 1]).cpu(), s=10, label="Mean", color="red")
            else:
                ax[i].scatter(posterior[i, :, 0].cpu(), posterior[i, :, 1].cpu(), s=1, label="Posterior")
                ax[i].scatter(real_phi[i, 0].cpu(), real_phi[i, 1].cpu(), s=10, label="True phi")
                ax[i].scatter(mean[i, 0].cpu(), mean[i, 1].cpu(), s=10, label="Mean", color="red")
            ax[i].legend()
            if xlim != None:
                ax[i].set_xlim(xlim)
            if ylim != None:
                ax[i].set_ylim(ylim)
    

def sample_posterior(model, x, 
                     n_steps=10, 
                     n_samples=1000):
    model.eval()
    posterior = []
    time_steps = torch.linspace(0.0, 1.0, n_steps + 1).to(device)
    
    for i in range(n_samples):
        # pred_phi = torch.randn(size=(x.shape[0], 2)).to(device)
        pred_phi = sample_init_dist(x.shape[0]).to(device)
        for i in range(n_steps):
            pred_phi = model.step(phi=pred_phi, x=x, t_start=time_steps[i], t_end=time_steps[i+1])
        posterior.append(pred_phi[:, None, :])

    posterior = torch.cat(posterior, dim=1).detach()
    return posterior


def fast_sample_posterior(model, 
                          x, 
                          n_steps=32, 
                          n_samples=1000, 
                          return_x=False):
    model.eval()
    time_steps = torch.linspace(0.0, 1.0, n_steps + 1).to(device)

    x_expanded = x.expand(n_samples, *x.shape).to(device)
    pred_phi = sample_init_dist(x_expanded.shape[:-1]).to(device)
    print(pred_phi.shape, x_expanded.shape)
    for i in range(n_steps):
        pred_phi = model.step(phi=pred_phi, x=x_expanded, t_start=time_steps[i], t_end=time_steps[i+1])
    if return_x:
        return pred_phi.detach(), x_expanded.detach()
    return pred_phi.detach()


def validate(phi,
             model,
             summary,
             plot=False,
             log_scale=False,
             xlim=None,
             ylim=None):
    model.eval()
    x_real = simulate(phi).detach().cpu()
    s = summary(x_real).to(device)
    
    phi_pred = fast_sample_posterior(model, 
                                     s, 
                                     n_steps=32, 
                                     n_samples=1000).detach().cpu()

    mean = phi_pred.mean(dim=1)
    std = (phi_pred - mean[:, None, :]).pow(2).mean(dim=1).pow(0.5)
    for i in range(mean.shape[0]):
        print(f"True: {phi[i].cpu()}, Mean: {mean[i]}, STD: {std[i]}")
    
    if plot:
        plot_posterior(phi_pred, phi, log_scale=log_scale, xlim=xlim, ylim=ylim)
        
        x_pred = simulate(phi_pred[0]).detach().cpu()

        S_real, I_real, R_real = x_real[0, :, 0], x_real[0, :, 1], x_real[0, :, 2]
        
        _, ax = plt.subplots(3, 1)
        ax[0].plot(S_real, linestyle="--", color="green", label="real")
        ax[1].plot(I_real, linestyle="--", color="red", label="real")
        ax[2].plot(R_real, linestyle="--", color="blue", label="real")
        
        for i in range(x_pred.shape[0]):
            S_pred, I_pred, R_pred = x_pred[i, :, 0], x_pred[i, :, 1], x_pred[i, :, 2]
        
            ax[0].plot(S_pred, color="green", label="pred", alpha=0.1)
            ax[1].plot(I_pred, color="red",   label="pred", alpha=0.1)
            ax[2].plot(R_pred, color="blue",  label="pred", alpha=0.1)
            if i == 0:
                [ax[j].legend() for j in range(3)]
        plt.tight_layout()

# %%
from sfmpe.tasks.SIR import SIRTask


config_path = './configs/sir_config.yaml'
with open(config_path) as f:
    config = yaml.safe_load(f)
device = 'cpu'
sir_task = SIRTask(config, device)



def validate2(phi,
             model,
             summary,
             plot=False,
             log_scale=False,
             xlim=None,
             ylim=None):
    model.eval()
    x_real = sir_task.simulate(phi).detach().cpu()
    s = sir_task.summarize(x_real).to(device)
    
    phi_pred = fast_sample_posterior(model, 
                                     s, 
                                     n_steps=32, 
                                     n_samples=1000).detach().cpu()
    
    mean = phi_pred.mean(dim=0)
    # std = (phi_pred - mean[:, None, :]).pow(2).mean(dim=1).pow(0.5)
    std = phi_pred.std(dim=0)
    
    print(f"True: {phi.cpu()}, Mean: {mean}, STD: {std}")
    
    if plot:
        plot_posterior(phi_pred, phi, log_scale=log_scale, xlim=xlim, ylim=ylim)
        
        x_pred = simulate(phi_pred).detach().cpu()

        S_real, I_real, R_real = x_real[0, :, 0], x_real[0, :, 1], x_real[0, :, 2]
        
        _, ax = plt.subplots(3, 1)
        ax[0].plot(S_real, linestyle="--", color="green", label="real")
        ax[1].plot(I_real, linestyle="--", color="red", label="real")
        ax[2].plot(R_real, linestyle="--", color="blue", label="real")
        
        for i in range(x_pred.shape[0]):
            S_pred, I_pred, R_pred = x_pred[i, :, 0], x_pred[i, :, 1], x_pred[i, :, 2]
        
            ax[0].plot(S_pred, color="green", label="pred", alpha=0.1)
            ax[1].plot(I_pred, color="red",   label="pred", alpha=0.1)
            ax[2].plot(R_pred, color="blue",  label="pred", alpha=0.1)
            if i == 0:
                [ax[j].legend() for j in range(3)]
        plt.tight_layout()
    
def validate3(phi,
            model,
            summary,
            plot=False,
            log_scale=False,
            xlim=None,
            ylim=None):
    def dist_plot(*dists, true_param=None, pred_param=None):
        # assert len(dist1.shape) == len(dist2.shape) and dist1.shape[-1] == dist2.shape[-1]
        theta_dim = dists[0].shape[-1]
        num_bins  = [int(dists[i].shape[0] ** 0.5) for i in range(len(dists))]
        
        _, ax = plt.subplots(len(dists), theta_dim, sharex='col', figsize=(3*theta_dim, 3*len(dists)))
        if len(dists) == 1:
            ax = [ax]
        for j in range(theta_dim):
            for thetas, i in zip(dists, range(len(dists))):
                counts, bins, patches = ax[i][j].hist(thetas[:, :, j], bins=num_bins[i], alpha=0.5, density=True)

                bin_centers = (bins[:-1] + bins[1:]) / 2

                ax[i][j].plot(bin_centers, counts, 'b-', linewidth=1)

                if true_param is not None:
                    ax[i][j].axvline(x=true_param[:, j], linestyle='--', color='green')
                
                if pred_param is not None:
                    ax[i][j].axvline(x=pred_param[:, j], linestyle='--', color='red')
                    
    model.eval()
    x_real = sir_task.simulate(phi).detach().cpu()
    s = sir_task.summarize(x_real).to(device)
    
    phi_pred = fast_sample_posterior(model, 
                                     s, 
                                     n_steps=32, 
                                     n_samples=1000).detach().cpu()
    
    mean = phi_pred.mean(dim=0)
    # std = (phi_pred - mean[:, None, :]).pow(2).mean(dim=1).pow(0.5)
    std = phi_pred.std(dim=0)
    
    print(f"True: {phi.cpu()}, Mean: {mean}, STD: {std}")
    # from sfmpe.utils.plotting import dist_plot

    dist_plot(phi_pred, true_param=phi, pred_param=mean)

# %%
from sfmpe.data.round_dataset import RoundDataset
from sfmpe.data.simulation_store import SimulationStore
import torch.distributions as dist


import yaml
import torch
import time

beta_dist = dist.Beta(torch.tensor(0.5), torch.tensor(0.5))

def train(model, 
          summary,
          sim_parameters,
          optimizer, 
          loss_fn,
          dataset=None,
          epochs=2000,
          path="./models",
          show_every=None, 
          show_loss=False,
          phi_val=None):
    
    model.train()
    sir = sim_parameters["sir"]
    T_max = sim_parameters["T_max"]

    losses = []
    min_loss = torch.inf

    if not show_every is None:
        show_loss = True

    def shuffle(x, n=10000, i=None, dim=0, noise=False):
        if i:
            if i < x.size(0):
                
                out = x[i:min(i+n, x.size(0)-1)]
                # if noise:
                    # out += 0.01*torch.randn_like(out) 
                    # print("hello")
                return out
        return x
        # indices = torch.randperm(x.size(dim))[:n]
        # shuffled = torch.index_select(x, dim, indices)
        # if noise:
        #     shuffled += 0.1*torch.randn_like(shuffled) 
        return shuffled
    
    def preprocess(theta, x):
        return torch.exp(torch.log(theta) + 0.001*torch.randn_like(theta)), \
               x + 0.01 * torch.randn_like(x)
    
    for i in range(epochs+1):
        if dataset is None:
            # phi_1 = sample_prior(1000).to(device)
            # x = simulate(phi_1, sir, T_max).to(device)
            # s = summary(x).to(device)
            phi_1, s = sir_task.simulate_dataset((10000, ))
        else:
            # phi_1, s = shuffle(dataset.theta, i=i, noise=False), shuffle(dataset.x, i=i, noise=False)
            phi_1, s = preprocess(dataset.theta, dataset.x)
        
        phi_0 = sample_init_dist(phi_1.shape[:-1]).to(device)
        t = torch.rand(*phi_1.shape[:-1], 1).to(device)
        # t = beta_dist.sample((phi_1.shape[0], 1)).to(device)
        
        phi_t = (1 - t) * phi_0 + t * phi_1
        dphi_t = phi_1 - phi_0

        v = model(t=t, x=s, phi=phi_t)
        loss = loss_fn(v, dphi_t)
        losses.append(loss.detach().item())

        if loss < min_loss:
            torch.save(model.state_dict(), path)
        
        if show_loss and i % show_every == 0:
            # if phi_val is not None:
            #     validate2(phi, model, summary)#, plot=True, log_scale=True, xlim=[-4, 1], ylim=[-3, -1])
            print(f"Epoch: {i}, Loss: {losses[i]:.4f}")#, Time: {(time.time() - s):.2f}")
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    return losses

def pipeline(model,
             summary,
             optimizer,
             sim_parameters,
             train_model=True,
             epochs=2000, 
             show_every=200,
             device=torch.device(device),
             phi_val=None):
    if train_model:
        model.train()
        
        loss = torch.nn.MSELoss()
        
        datetime = time.strftime("%Y-%m-%d_%H_%M_%S")
        path = f"./models/SIR_{datetime}.pth.tar.gz" 
        
        from sfmpe.data.round_dataset import RoundDataset
        from sfmpe.data.simulation_store import SimulationStore

    
        store = SimulationStore(".")
        theta, x = sir_task.simulate_dataset((10000, ))
        # theta = sample_prior(1000000, device=device)
        # x = handmade_summary(simulate(theta, sir, 90))
        store.add(theta, x, 0)
        dataset = RoundDataset(store, [0])


        losses = train(model, 
                       summary,
                       sim_parameters, 
                       optimizer, 
                       loss,
                       dataset=dataset,
                       path=path, 
                       epochs=epochs, 
                       show_every=show_every,
                       phi_val=phi_val)
        plt.plot(losses)
        return losses
    
    else:
        assert os.path.exists(path)
        model.load_state_dict(torch.load(path, weights_only=True, map_location=torch.device(device)))
        model.eval()

phi = torch.tensor([[0.4284, 0.1615]]).to(device)
x = simulate(phi)
print(phi)

simple_model = CondFlow(2, 5, 64).to(device)
optimizer = torch.optim.Adam(simple_model.parameters(), lr=5e-4)
sim_parameters = {"sir": (1000, 100, 0),
                  "T_max": 90}

losses = pipeline(simple_model,
                  handmade_summary,
                  optimizer,
                  sim_parameters,
                  train_model=True,
                  epochs=1000, 
                  show_every=100,
                  phi_val=phi)
# Out:
# tensor([[0.4284, 0.1615]])
# Epoch: 0, Loss: 0.2040
# Epoch: 100, Loss: 0.0976
# Epoch: 200, Loss: 0.0465
# Epoch: 300, Loss: 0.0384
# Epoch: 400, Loss: 0.0327
# Epoch: 500, Loss: 0.0289
# Epoch: 600, Loss: 0.0259
# Epoch: 700, Loss: 0.0254
# Epoch: 800, Loss: 0.0254
# Epoch: 900, Loss: 0.0243
# Epoch: 1000, Loss: 0.0240

# %%
phi_real = sir_task.sample_prior((100,))
x_real = sir_task.simulate(phi_real).detach().cpu()
s = sir_task.summarize(x_real).to(device)
print(phi_real.shape, s.shape)
phi_pred = fast_sample_posterior(simple_model, 
                                     s, 
                                     n_steps=32, 
                                     n_samples=100).detach().cpu()
    
# mean = phi_pred.mean(dim=0)
s.shape
# Out:
# torch.Size([100, 2]) torch.Size([100, 5])
# torch.Size([100, 100, 2]) torch.Size([100, 100, 5])
# torch.Size([100, 5])

# %%
phi = sample_prior((1,))
validate3(phi, simple_model, handmade_summary, plot=True, log_scale=False)#, xlim=[-4, 1], ylim=[-3, -1])
# Out:
# torch.Size([1000, 1, 2]) torch.Size([1000, 1, 5])
# True: tensor([[0.0356, 0.0558]]), Mean: tensor([[0.0647, 0.1083]]), STD: tensor([[0.0347, 0.0591]])

# %%
def seq_pipeline(x,
                 model,
                 summary,
                 optimizer,
                 sim_parameters,
                 dataset_size=10000,
                 runs=3,
                 train_model=True,
                 epochs=1000, 
                 show_every=200,
                 device=torch.device(device),
                 phi_val=None):
    if train_model:
        model.train()
        
        loss = torch.nn.MSELoss()
        
        datetime = time.strftime("%Y-%m-%d_%H_%M_%S")
        path = f"./models/SIR_{datetime}.pth.tar.gz" 
        
        store = SimulationStore(".")
        theta, x = sir_task.simulate_dataset((10000, 1))
        # theta = sample_prior(1000000, device=device)
        # x = handmade_summary(simulate(theta, sir, 90))
        store.add(theta, x, 0)
        dataset = RoundDataset(store, [0])


        losses = []
        print("Round 1")
        losses += train(model, 
                       summary, 
                       sim_parameters, 
                       optimizer, 
                       loss, 
                       path=path, 
                       epochs=epochs,
                       dataset=dataset, 
                       show_every=show_every,
                       phi_val=phi_val)
        validate3(phi_val, model, summary, plot=True, log_scale=False)#True , xlim=[-4, 1], ylim=[-3, -1])
        x = simulate(phi_val)
        s = summary(x).to(device)
        print(s.shape, phi_val.shape)
        for i in range(runs - 1):
            print(f"Round {i+2}")
            phi, features = fast_sample_posterior(model, s, n_samples=dataset_size, return_x=True)
            print(phi, features)
            store.add(phi, features, i+2)
            dataset = RoundDataset(store, [i+2])
            losses += train(model, 
                            summary, 
                            sim_parameters, 
                            optimizer, 
                            loss, 
                            dataset=dataset,
                            path=path, 
                            epochs=epochs, 
                            show_every=show_every,
                            phi_val=phi_val)
            validate3(phi_val, model, summary, plot=True, log_scale=False)#True , xlim=[-4, 1], ylim=[-3, -1])
        return losses, dataset
    
    else:
        assert os.path.exists(path)
        model.load_state_dict(torch.load(path, weights_only=True, map_location=torch.device(device)))
        model.eval()

# %%
seq_model = CondFlow(2, 5, 64).to(device)
optimizer = torch.optim.Adam(seq_model.parameters(), lr=1e-4)
sim_parameters = {"sir": (1000, 100, 0),
                  "T_max": 90}

losses, dataset = seq_pipeline(x,
                      seq_model,
                      handmade_summary,
                      optimizer,
                      sim_parameters,
                      train_model=True,
                      dataset_size=10000,
                      runs=4,
                      epochs=100, 
                      show_every=20,
                      phi_val=phi)
# Out:
# Round 1
# Epoch: 0, Loss: 0.2580
# Epoch: 20, Loss: 0.2334
# Epoch: 40, Loss: 0.2110
# Epoch: 60, Loss: 0.1957
# Epoch: 80, Loss: 0.1784
# Epoch: 100, Loss: 0.1646
# torch.Size([1000, 1, 2]) torch.Size([1000, 1, 5])
# True: tensor([[0.0356, 0.0558]]), Mean: tensor([[0.4234, 0.3230]]), STD: tensor([[0.2848, 0.2819]])
# torch.Size([1, 5]) torch.Size([1, 2])
# Round 2
# torch.Size([10000, 1, 2]) torch.Size([10000, 1, 5])
# tensor([[[-0.0433,  0.6070]],
#
#         [[ 0.6288,  0.0659]],
#
#         [[ 0.9080,  0.2786]],
#
#         ...,
#
#         [[ 0.1115,  0.7424]],
#
#         [[ 0.7250,  0.1929]],
#
#         [[ 0.7796,  0.7795]]]) tensor([[[ 0.2409, -0.9790, -1.3847,  0.1008, -0.6920]],
#
#         [[ 0.2409, -0.9790, -1.3847,  0.1008, -0.6920]],
#
#         [[ 0.2409, -0.9790, -1.3847,  0.1008, -0.6920]],
#
#         ...,
#
#         [[ 0.2409, -0.9790, -1.3847,  0.1008, -0.6920]],
#
#         [[ 0.2409, -0.9790, -1.3847,  0.1008, -0.6920]],
#
#         [[ 0.2409, -0.9790, -1.3847,  0.1008, -0.6920]]])
# Epoch: 0, Loss: nan
# Epoch: 20, Loss: nan
# Epoch: 40, Loss: nan
# Epoch: 60, Loss: nan
# Epoch: 80, Loss: nan
# Epoch: 100, Loss: nan
# torch.Size([1000, 1, 2]) torch.Size([1000, 1, 5])
# True: tensor([[0.0356, 0.0558]]), Mean: tensor([[nan, nan]]), STD: tensor([[nan, nan]])
# c:\Users\Mikhail\miniconda3\envs\python310\lib\site-packages\matplotlib\axes\_axes.py:6973: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# c:\Users\Mikhail\miniconda3\envs\python310\lib\site-packages\matplotlib\axes\_axes.py:6974: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 6
#       2 optimizer = torch.optim.Adam(seq_model.parameters(), lr=1e-4)
#       3 sim_parameters = {"sir": (1000, 100, 0),
#       4                   "T_max": 90}
# ----> 6 losses, dataset = seq_pipeline(x,
#       7                       seq_model,
#       8                       handmade_summary,
#       9                       optimizer,
#      10                       sim_parameters,
#      11                       train_model=True,
#      12                       dataset_size=10000,
#      13                       runs=4,
#      14                       epochs=100,
#      15                       show_every=20,
#      16                       phi_val=phi)
#
# Cell In[107], line 61, in seq_pipeline(x, model, summary, optimizer, sim_parameters, dataset_size, runs, train_model, epochs, show_every, device, phi_val)
#      50         dataset = RoundDataset(store, [i+2])
#      51         losses += train(model,
#      52                         summary,
#      53                         sim_parameters,
#    (...)
#      59                         show_every=show_every,
#      60                         phi_val=phi_val)
# ---> 61         validate3(phi_val, model, summary, plot=True, log_scale=False)#True , xlim=[-4, 1], ylim=[-3, -1])
#      62     return losses, dataset
#      64 else:
#
# Cell In[78], line 101, in validate3(phi, model, summary, plot, log_scale, xlim, ylim)
#      98 print(f"True: {phi.cpu()}, Mean: {mean}, STD: {std}")
#      99 # from sfmpe.utils.plotting import dist_plot
# --> 101 dist_plot(phi_pred, true_param=phi, pred_param=mean)
#
# Cell In[78], line 73, in validate3.<locals>.dist_plot(true_param, pred_param, *dists)
#      71 for j in range(theta_dim):
#      72     for thetas, i in zip(dists, range(len(dists))):
# ---> 73         counts, bins, patches = ax[i][j].hist(thetas[:, :, j], bins=num_bins[i], alpha=0.5, density=True)
#      75         bin_centers = (bins[:-1] + bins[1:]) / 2
#      77         ax[i][j].plot(bin_centers, counts, 'b-', linewidth=1)
#
# File c:\Users\Mikhail\miniconda3\envs\python310\lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Mikhail\miniconda3\envs\python310\lib\site-packages\matplotlib\axes\_axes.py:7001, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6997 # Loop through datasets
#    6998 for i in range(nx):
#    6999     # this will automatically overwrite bins,
#    7000     # so that each histogram uses the same bins
# -> 7001     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7002     tops.append(m)
#    7003 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File c:\Users\Mikhail\miniconda3\envs\python310\lib\site-packages\numpy\lib\histograms.py:780, in histogram(a, bins, range, density, weights)
#     680 r"""
#     681 Compute the histogram of a dataset.
#     682
#    (...)
#     776
#     777 """
#     778 a, weights = _ravel_and_check_weights(a, weights)
# --> 780 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     782 # Histogram is an integer or a float array depending on the weights.
#     783 if weights is None:
#
# File c:\Users\Mikhail\miniconda3\envs\python310\lib\site-packages\numpy\lib\histograms.py:426, in _get_bin_edges(a, bins, range, weights)
#     423     if n_equal_bins < 1:
#     424         raise ValueError('`bins` must be positive, when an integer')
# --> 426     first_edge, last_edge = _get_outer_edges(a, range)
#     428 elif np.ndim(bins) == 1:
#     429     bin_edges = np.asarray(bins)
#
# File c:\Users\Mikhail\miniconda3\envs\python310\lib\site-packages\numpy\lib\histograms.py:323, in _get_outer_edges(a, range)
#     321     first_edge, last_edge = a.min(), a.max()
#     322     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 323         raise ValueError(
#     324             "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     326 # expand empty range to avoid divide by zero
#     327 if first_edge == last_edge:
#
# ValueError: autodetected range of [nan, nan] is not finite

# %%
plt.plot(losses)

# %%
validate2(phi, seq_model, handmade_summary, plot=True, log_scale=True, xlim=[-4, 1], ylim=[-3, -1])
# validate(phi, seq_model, handmade_summary, plot=True)
# validate(phi, seq_model, handmade_summary, plot=True)
# validate(phi, seq_model, handmade_summary, plot=True)
# Out:
# True: tensor([[0.4284, 0.1615]]), Mean: tensor([0.4048, 0.1714]), STD: tensor([0.0153, 0.0191])

# %%
# phi = sir_task.sample_prior((1, ))
phi = torch.tensor([[0.4284, 0.1615]]).to(device)
x = sir_task.simulate(phi)
s = sir_task.summarize(x)
phi_pred = fast_sample_posterior(seq_model, s)
plt.scatter(torch.log(phi_pred[:, 0]), torch.log(phi_pred[:, 1]), s=1)
plt.scatter(torch.log(phi[:, 0]), torch.log(phi[:, 1]), s=10)
